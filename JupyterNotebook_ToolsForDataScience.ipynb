# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h6 style="color:red">Exercise 2 : </h6><h2>Gunes Gursoy's Notebook </h2>

# %% [markdown]
# <h6 style="color:red">Exercise 3 :</h6><i> This homework includes various data science languages,libraries,tools and some mathematical operations</i>

# %% [markdown]
# <h6 style="color:red">Exercise 4 :</h6><b>List of Data Science Languages </b>
# <ol>
#     <li> Python </li>
#     <li> R </li>
#     <li> Scala </li>
#     <li> Julia </li>
#     <li> SQL </li>
#     <li> JAVA </li>
#     <li> C++ </li>
# </ol>

# %% [markdown]
# <h6 style="color:red">Exercise 5 :</h6><b>List of Data Science Libraries </b>
# <ol>
#     <li> Scikit Learn </li>
#     <li> Tensorflow </li>
#     <li> PyTorch</li>
#     <li> Keras </li>
#     <li> Pandas </li>
#     <li> Numpy </li>
#     <li> Matplotlib </li>
#     <li> Seaborn </li>
#     <li> SciPy </li>
# </ol>

# %% [markdown]
# <h6 style="color:red">Exercise 6 :</h6><p>
# <b> List of Data Science tools </b>
# <table align=left>
#     <tr>
#         <th align=left> Tool Name </th>
#     </tr>
#     <tr>
#         <td>Apache Airflow</td>
#     </tr>
#     <tr>
#         <td>Apache Kafka</td>
#     </tr>
#     <tr>
#         <td>Apache Nifi</td>
#     </tr>
#     <tr>
#         <td>Relationship DBs : MySQL, PostreSQL</td>
#     </tr>
#     <tr>
#         <td>NoSQL : MongoDB, Apache CouchDB, Apache Cassandra</td>
#     </tr>
#     <tr>
#         <td>FileBased Tools : Hadoop File System, Ceph, Elastic Search</td>
#     </tr>
#     <tr>
#         <td>HUE</td>
#     </tr>
#      <tr>
#         <td>Kibona</td>
#     </tr>
#      <tr>
#         <td>SuperSet</td>
#     </tr>
#      <tr>
#         <td>Apache Spark ML</td>
#     </tr>
#      <tr>
#         <td>SELDON</td>
#     </tr>
# </table>

# %% [markdown]
# <h6 style="color:Red">Exercise 7: </h6>
# <b> Arithmetic Expression Examples </b>

# %%
#Exercise 8
a = 5
b = 6
Multiply = a*b
Sum = a+b
print("a is 5 and b is 6")
print("Multiply : ", Multiply)
print("Sum : ", Sum )
# Out:
# a is 5 and b is 6
# Multiply :  30
# Sum :  11

# %%
#Exercise 9
minutes = 360
hour = minutes /60
print(hour,"hour")
# Out:
# 6.0 Hour

# %% [markdown]
# <h6 style="color:red">Exercise 10 : </h6>
# <b> List Objectives </b>
#
# <ol>
# <li> Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt) </li>
#
# <li>Exercise 3 - Create a markdown cell for an introduction. (1 pt)</li>
#
# <li>Exercise 4 - Create a markdown cell to list data science languages. (3 pts)</li>
#
# <li>Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)</li>
#
# <li>Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)</li>
#
# <li>Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)</li>
#
# <li>Exercise 8 - Create a code cell to multiply and add numbers.(2 pts)</li>
#
# <li>Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)</li>
#
# <li>Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)</li>
#
# <li>Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)</li>
#
# <li>Exercise 12 - Share your notebook through GitHub (3 pts) </li>
# <li>Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt) </li>
# </ol>

# %% [markdown]
# <h6 style="color:red"> Exercise 11 : </h6>
# <i> <b>Author's Name:</b> Güneş Gürsoy</i>

# %% [markdown]
# <h6 style="color:red"> Exercise 12 :</h6>
# <a href = "https://github.com/gunesgursoy/ibm_dataScience.git"> https://github.com/gunesgursoy/ibm_dataScience.git </a>

# %% [markdown]
# <h6 style="color:red"> Exercise 13 : </h6>
# <h6 style="color:red"> Screen Shot</h6>

# %% [markdown]
# ![image.png](attachment:image.png)
